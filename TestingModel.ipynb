# %% [markdown]
# <a href="https://colab.research.google.com/github/nashrah-18/YourIndianTranslatorupdated/blob/main/TestingModel.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Import libraries
from transformers import AutoModelForSeq2SeqLM, AutoTokenizer

# %%
# Load pre-trained model and tokenizer
model_name = "nashrah18/indian_translatorv1"
model = AutoModelForSeq2SeqLM.from_pretrained(model_name, from_tf=True)
tokenizer = AutoTokenizer.from_pretrained(model_name)
# Out:
# config.json:   0%|          | 0.00/1.38k [00:00<?, ?B/s]
# tf_model.h5:   0%|          | 0.00/306M [00:00<?, ?B/s]
# All TF 2.0 model weights were used when initializing MarianMTModel.
#
# Some weights of MarianMTModel were not initialized from the TF 2.0 model and are newly initialized: ['model.encoder.embed_tokens.weight', 'model.decoder.embed_tokens.weight', 'lm_head.weight', 'lm_head.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# generation_config.json:   0%|          | 0.00/288 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/849 [00:00<?, ?B/s]
# source.spm:   0%|          | 0.00/812k [00:00<?, ?B/s]
# target.spm:   0%|          | 0.00/1.07M [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/2.22M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/74.0 [00:00<?, ?B/s]
# ...

# %%
# Input text
input_text = "How can I protect myself from pickpocketing in crowded areas in India?"

# Tokenize input text
inputs = tokenizer(input_text, return_tensors="pt")

# Run model inference
outputs = model.generate(inputs["input_ids"], max_length=50)

# Print output
print(tokenizer.decode(outputs[0], skip_special_tokens=True))
# Out:
# भीड़भाड़ वाली जगहों पर जेब चोर से कैसे बचूँ भाई?
